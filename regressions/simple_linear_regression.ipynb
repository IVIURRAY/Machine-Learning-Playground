# %%
# Import libarys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Import the dataset
root = '/Users/Haydn/Documents/Code/Jupyter/Machine Learning A-Z/1.0 - Example Data/'
data_file = root + 'Part 2 - Regression/Simple Linear Regression/Salary_Data.csv'
dataset = pd.read_csv(data_file)
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Splitting features and outcomes
x = dataset.iloc[:, :1].values
y = dataset.iloc[:, 1:].values

# %%
# Split dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)
print('X Training Size: %s\n' % len(x_train), x_train, '\nX Test Size: %s\n' % len(x_test), x_test, '\nY Training Size: %s\n' % len(y_train), y_train, '\nY Test Size: %s\n' % len(y_test), y_test)
# Out:
# X Training Size: 20
#  [[ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]
# X Test Size: 10
#  [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]]
# Y Training Size: 20
#  [[ 56642.]
#  [ 66029.]
#  [ 64445.]
#  [ 61111.]
#  [113812.]
#  [ 91738.]
#  [ 46205.]
#  [121872.]
#  [ 60150.]
#  [ 39891.]
#  [ 81363.]
#  [ 93940.]
#  [ 57189.]
#  [ 54445.]
#  [105582.]
#  [ 43525.]
#  [ 39343.]
#  [ 98273.]
#  [ 67938.]
#  [ 56957.]]
# Y Test Size: 10
#  [[ 37731.]
#  [122391.]
#  [ 57081.]
#  [ 63218.]
#  [116969.]
#  [109431.]
#  [112635.]
#  [ 55794.]
#  [ 83088.]
#  [101302.]]

# %%
# Make a Simple Linear Regression
simple_linear_regression = LinearRegression().fit(x_train, y_train)

# %%
# Predict on our test set
y_prediction = simple_linear_regression.predict(x_test)
print('Values that the model predicted: \n', y_prediction, '\nThis was the real salaries: \n', y_test, '\nThe difference:\n', y_prediction - y_test)
# Out:
# Values that the model predicted:
#  [[ 40835.10590871]
#  [123079.39940819]
#  [ 65134.55626083]
#  [ 63265.36777221]
#  [115602.64545369]
#  [108125.8914992 ]
#  [116537.23969801]
#  [ 64199.96201652]
#  [ 76349.68719258]
#  [100649.1375447 ]]
# This was the real salaries:
#  [[ 37731.]
#  [122391.]
#  [ 57081.]
#  [ 63218.]
#  [116969.]
#  [109431.]
#  [112635.]
#  [ 55794.]
#  [ 83088.]
#  [101302.]]
# The difference:
#  [[ 3104.10590871]
#  [  688.39940819]
#  [ 8053.55626083]
#  [   47.36777221]
#  [-1366.35454631]
#  [-1305.1085008 ]
#  [ 3902.23969801]
#  [ 8405.96201652]
#  [-6738.31280742]
#  [ -652.8624553 ]]

# %%
# Visualise the training result more
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, simple_linear_regression.predict(x_train))
plt.title('Salary Vs Experience (Training Set)')
plt.xlabel('Yrs Exp')
plt.ylabel('Salary')
plt.show()

# %%
# Visualise the test result more
plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, simple_linear_regression.predict(x_train))
# we dont use x_test here ^^ as we want to see the regression line
# that was created when training our model.
plt.title('Salary Vs Experience (Test Set)')
plt.xlabel('Yrs Exp')
plt.ylabel('Salary')
plt.show()
